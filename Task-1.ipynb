# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("books_data.csv")
df.head()
# Out:
#                                    title  price  rating  \
# 0                   A Light in the Attic  51.77       3
# 1                     Tipping the Velvet  53.74       1
# 2                             Soumission  50.10       1
# 3                          Sharp Objects  47.82       4
# 4  Sapiens: A Brief History of Humankind  54.23       5
#
#                                               banner availability
# 0  https://books.toscrape.com/media/cache/2c/da/2...     In stock
# 1  https://books.toscrape.com/media/cache/26/0c/2...     In stock
# 2  https://books.toscrape.com/media/cache/3e/ef/3...     In stock
# 3  https://books.toscrape.com/media/cache/32/51/3...     In stock
# 4  https://books.toscrape.com/media/cache/be/a5/b...     In stock

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.columns
# Out:
# Index(['title', 'price', 'rating', 'banner', 'availability'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1000 non-null   object
#  1   price         1000 non-null   float64
#  2   rating        1000 non-null   int64
#  3   banner        1000 non-null   object
#  4   availability  1000 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
df.isnull().sum()
# Out:
# title           0
# price           0
# rating          0
# banner          0
# availability    0
# dtype: int64

# %%
df.describe()
# Out:
#             price       rating
# count  1000.00000  1000.000000
# mean     35.07035     2.923000
# std      14.44669     1.434967
# min      10.00000     1.000000
# 25%      22.10750     2.000000
# 50%      35.98000     3.000000
# 75%      47.45750     4.000000
# max      59.99000     5.000000

# %%
df["rating"].value_counts().sort_index()
# Out:
# rating
# 1    226
# 2    196
# 3    203
# 4    179
# 5    196
# Name: count, dtype: int64

# %%
df.sort_values(by="price", ascending=False).head(10)
# Out:
#                                                  title  price  rating  \
# 648                 The Perfect Play (Play by Play #1)  59.99       3
# 617                  Last One Home (New Beginnings #1)  59.98       3
# 860                   Civilization and Its Discontents  59.95       2
# 560                     The Barefoot Contessa Cookbook  59.92       5
# 366                          The Diary of a Young Girl  59.90       3
# 657  The Bone Hunters (Lexy Vaughan & Steven Macaul...  59.71       3
# 133  Thomas Jefferson and the Tripoli Pirates: The ...  59.64       1
# 387                      Boar Island (Anna Pigeon #19)  59.48       3
# 549  The Man Who Mistook His Wife for a Hat and Oth...  59.45       4
# 393                          The Improbability of Love  59.45       1
#
#                                                 banner availability
# 648  https://books.toscrape.com/media/cache/40/16/4...     In stock
# 617  https://books.toscrape.com/media/cache/e4/0a/e...     In stock
# 860  https://books.toscrape.com/media/cache/4d/a6/4...     In stock
# 560  https://books.toscrape.com/media/cache/dd/07/d...     In stock
# 366  https://books.toscrape.com/media/cache/83/d5/8...     In stock
# 657  https://books.toscrape.com/media/cache/ee/d4/e...     In stock
# 133  https://books.toscrape.com/media/cache/97/47/9...     In stock
# 387  https://books.toscrape.com/media/cache/d5/81/d...     In stock
# 549  https://books.toscrape.com/media/cache/92/fe/9...     In stock
# 393  https://books.toscrape.com/media/cache/06/49/0...     In stock

# %%
df["rating"].value_counts().sort_index().plot(kind="bar",color = 'c')
plt.xlabel("Rating")
plt.ylabel("Number of Books")
plt.title("Book Count by Rating")
plt.show()

# %%
df.to_csv("scraped_books_data_cleaned.csv", index=False)
